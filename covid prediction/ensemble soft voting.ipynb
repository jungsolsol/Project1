# %%
import pandas as pd
import numpy as np

# %%
efficientnet = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/covid/efficientnet prediction.csv')

# %%
custom_cnn = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/covid/predictioncustom_CNN.csv')

# %%
custom_cnn2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/covid/custom_cnn prediction.csv')

# %%
resnet = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/covid/resnet prediction.csv')

# %%
temp = pd.DataFrame()
temp['efficientnet'] = efficientnet['1']
temp['custom_cnn'] = custom_cnn['1']
temp['custom_cnn2'] = custom_cnn2['1']
temp['resnet'] = resnet['1']
temp
# Out:
#     efficientnet  custom_cnn  custom_cnn2    resnet
# 0       0.129722    0.000168     0.027700  0.011411
# 1       0.499473    0.009233     0.150648  0.609546
# 2       0.129632    0.142233     0.183495  0.659353
# 3       0.416239    0.936359     0.657093  0.617523
# 4       0.049007    0.484517     0.012090  0.216283
# ..           ...         ...          ...       ...
# 95      0.010209    0.000008     0.035550  0.004350
# 96      0.999992    0.999576     0.993906  0.986145
# 97      0.652843    0.994597     0.756704  0.696947
# 98      0.962858    0.999796     0.984666  0.997506
# 99      0.004019    0.936309     0.987305  0.292371
#
# [100 rows x 4 columns]

# %%
result = custom_cnn + custom_cnn2 + resnet
result = result.apply(np.argsort, axis=1)
result['1']
# Out:
# 0     0
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    1
# 97    1
# 98    1
# 99    1
# Name: 1, Length: 100, dtype: int64

# %%
sample = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/covid/sample_submission.csv')

# %%
sample
# Out:
#    file_name  COVID
# 0      0.png      0
# 1      1.png      0
# 2      2.png      0
# 3      3.png      0
# 4      4.png      0
# ..       ...    ...
# 95    95.png      0
# 96    96.png      0
# 97    97.png      0
# 98    98.png      0
# 99    99.png      0
#
# [100 rows x 2 columns]

# %%
sample['COVID'] = result['1']

df = sample

# %%
df
# Out:
#    file_name  COVID
# 0      0.png      0
# 1      1.png      0
# 2      2.png      0
# 3      3.png      1
# 4      4.png      0
# ..       ...    ...
# 95    95.png      0
# 96    96.png      1
# 97    97.png      1
# 98    98.png      1
# 99    99.png      1
#
# [100 rows x 2 columns]

# %%
df.to_csv('prediction1.csv', index=False)

# %% [markdown]
# ensemble1  custom_cnn + custom_cnn2 + efficientnet
#
# ensemble2  custom_cnn + custom_cnn2 + efficientnet + resnet
#
# ensemble3  custom_cnn + custom_cnn2
#
# ensemble4  custom_cnn + custom_cnn2 + resnet
