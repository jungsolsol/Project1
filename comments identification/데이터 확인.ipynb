# %%
import pandas as pd

# %%
train_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/traffic forecasting/Project1/comments identification/data/back taranslation train.csv')
papago =  pd.read_csv('/content/drive/MyDrive/Colab Notebooks/traffic forecasting/Project1/comments identification/data/papago train.csv')
google = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/traffic forecasting/Project1/comments identification/data/google train.csv')
pororo = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/traffic forecasting/Project1/comments identification/data/pororo train.csv')

# %%
data = pd.DataFrame()

# %%
data['title'] = train_df['title']

# %%
data['new title'] = papago['title']

# %%
data['papago title'] = papago['papago title']

# %%
data['google title'] = google['google title']

# %%
data['pororo title'] = pororo['pororo title']

# %%
data
# Out:
#                                                   title  ...                                   pororo title
# 0            "'미스터 션샤인' 변요한, 김태리와 같은 양복 입고 학당 방문! 이유는?"  ...  선샤인 씨가 변요한 김태리와 같은 정장을 입고 학교를 방문한 이유는 그 때문이다.
# 1     "[SC현장]""극사실주의 현실♥""…'가장 보통의 연애' 김래원X공효진, 16년만...  ...                       16년 만의 로맨틱한 현실, 김래원 X공효진
# 2                "손연재, 리듬체조 학원 선생님 ""하고 싶은 일 해서 행복하다"""  ...                 리듬체조연구소 손연재가 하고 싶은 일을 하면서 기쁘다.
# 3                  "'섹션TV' 김해숙 ""'허스토리' 촬영 후 우울증 얻었다"""  ...                          김해숙의 이야기를 촬영한 뒤 우울했다.
# 4     "[단독] 임현주 아나운서 “‘노브라 챌린지’ 방송 덕에 낸 용기, 자연스런 논의의...  ...           임현주 아나운서의 노브라 챌린지 방송이 만든 자연스러운 토론이라면
# ...                                                 ...  ...                                            ...
# 8362                  "배우 이필립, SNS 스타 연인에게 초호화 프러포즈 눈길"  ...                                            NaN
# 8363  "[SC이슈]""마약·백스텝·김새롬 탓"" '실형 피한' 이찬오, 이미지는 치명상(...  ...                                            NaN
# ...

# %%
data.to_csv('/content/drive/MyDrive/Colab Notebooks/traffic forecasting/Project1/comments identification/data/back taranslation train.csv', index=False)

# %%
data2 = pd.DataFrame()

# %%
train_df
# Out:
#                                                   title  ...  hate
# 0            "'미스터 션샤인' 변요한, 김태리와 같은 양복 입고 학당 방문! 이유는?"  ...  none
# 1     "[SC현장]""극사실주의 현실♥""…'가장 보통의 연애' 김래원X공효진, 16년만...  ...  hate
# 2                "손연재, 리듬체조 학원 선생님 ""하고 싶은 일 해서 행복하다"""  ...  hate
# 3                  "'섹션TV' 김해숙 ""'허스토리' 촬영 후 우울증 얻었다"""  ...  none
# 4     "[단독] 임현주 아나운서 “‘노브라 챌린지’ 방송 덕에 낸 용기, 자연스런 논의의...  ...  none
# ...                                                 ...  ...   ...
# 8362                  "배우 이필립, SNS 스타 연인에게 초호화 프러포즈 눈길"  ...  hate
# 8363  "[SC이슈]""마약·백스텝·김새롬 탓"" '실형 피한' 이찬오, 이미지는 치명상(...  ...  hate
# 8364        "[POP이슈]""그들만의 세상""…홍상수♥김민희, 새해데이트에 '반응싸늘'"  ...  none
# 8365                   [종합] '시크릿 마더' 김소연 누가 죽였나…송윤아와 갈등  ...  none
# 8366                 "허지웅·소속사 ""악성림프종 진단, 치료 전념"" (공식)"  ...  hate
#
# [8367 rows x 4 columns]

# %%
data2['comment'] = train_df['comment']

# %%
data2['papago comment'] = papago['papago comment']

# %%
data2['google comment'] = google['google comment']

# %%
data2
# Out:
#                                                 comment  ...                                     google comment
# 0                                        김태리 정말 연기잘해 진짜  ...                                   김태리는 연기를 정말 잘한다.
# 1                              공효진 발연기나이질생각이읍던데 왜계속주연일까  ...                     공효진 연기 늙어가는데 내가 계속 주연을 맡는 이유는?
# 2     누구처럼 돈만 밝히는 저급인생은 살아가지마시길~~ 행복은 머니순이 아니니깐 작은거에...  ...  남들처럼 돈만 공개하는 하찮은 삶을 살지 마세요~~ 행복은 돈순이 아니니 작은것에 ...
# 3                                              일본 축구 져라  ...                                          일본 축구를 잃다
# 4                            난 절대로 임현주 욕하는인간이랑은 안논다 @.@  ...                           임현주 욕하는 사람이랑 절대 안놀아요 @.@
# ...                                                 ...  ...                                                ...
# 8362  아니 근데.튜닝한사람은 프러포즈받지도.결혼도못함?ㅋㅋㅋ지들은 돈없어서 못하는것들이ㅋ...  ...  아니, 하지만. 동조한 사람은 제안을 받지 않습니다. 결혼 못해요? ㅋㅋㅋㅋ 돈없어...
# ...

# %% [markdown]
# 트레인 테스트 데이터 같은 title 비율 찾기

# %%
train_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/traffic forecasting/Project1/comments identification/data/back taranslation train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/traffic forecasting/Project1/comments identification/data/back taranslation test.csv')

# %%
train_df.iloc[:,0:2]
# Out:
#                                            title                                            comment
# 0            미스터 션샤인 변요한 김태리와 같은 양복 입고 학당 방문 이유는                                     김태리 정말 연기잘해 진짜
# 1           극사실주의 현실 가장 보통의 연애 김래원X공효진 16년만의 랑데부                           공효진 발연기나이질생각이읍던데 왜계속주연일까
# 2               손연재 리듬체조 학원 선생님 하고 싶은 일 해서 행복하다.  누구처럼 돈만 밝히는 저급인생은 살아가지마시길~~ 행복은 머니순이 아니니깐 작은거에...
# 3                         김해숙 허스토리 촬영 후 우울증 얻었다.                                           일본 축구 져라
# 4     임현주 아나운서 노브라 챌린지 방송 덕에 낸 용기 자연스런 논의의 창 됐으면                         난 절대로 임현주 욕하는인간이랑은 안논다 @.@
# ...                                          ...                                                ...
# 8362              배우 이필립 SNS 스타 연인에게 초호화 프러포즈 눈길  아니 근데.튜닝한사람은 프러포즈받지도.결혼도못함?ㅋㅋㅋ지들은 돈없어서 못하는것들이ㅋ...
# 8363             마약 백스텝 김새롬 탓 실형 피한 이찬오 이미지는 치명상  그러니깐 여자를 잘만나야되~징글징글한것들 만나면 인생 끝가지 돌아가게 되는듯.. 근...
# ...

# %%
test_df.iloc[:,1:]
# Out:
#                                         title                                            comment
# 0         류현경 박성훈 공개연애 4년차 애정전선 이상무 의지 많이 된다.                                      둘다 넘 좋다~행복하세요
# 1        현금 유도 1인 1라면 골목식당 백종원 초심 잃은 도시락집에 경악               근데 만원이하는 현금결제만 하라고 써놓은집 우리나라에 엄청 많은데
# 2         입대 D 11 서은광의 슬픈 멜로디 비투비 눈물의 첫 체조경기장                                            누군데 얘네?
# 3    아이콘택트 리쌍 길 3년 전 결혼설 부인한 이유 공개 결혼 출산 숨겼다.  쑈 하지마라 짜식아!음주 1번은 실수, 2번은 고의, 3번은 인간쓰레기다.슬금슬금 ...
# 4            구하라 안검하수 반박 해프닝 당당하다 vs 그렇게까지 설전  안검하수 가지고 있는 분께 희망을 주고 싶은건가요? 수술하면 이렇게 자연스러워진다고...
# ..                                        ...                                                ...
# 506              최율 조재현 성추행 의혹 폭로 소속사 상황 파악 중               얜 그냥 봐도 아니다 ㅋ 고소당하면 어마어마한 금액 물어줘야할껄?
# 507          해투4 이서진 한지민 대본 리딩 격리설 해명 날씨가 좋아서                     대박 게스트... 꼭 봐야징~ 컨셉이 바뀌니깐 재미지넹
# 508               박민영 김비서 행복했다 열애설엔 당당 미소였으니까  성형으로 다 뜯어고쳐놓고 예쁜척. 성형 전 니 얼굴 다 알고있다. 순자처럼 된장냄새...
# ...

# %%
x1 = train_df['title'].unique()

# %%
len(x1)
# Out:
# 1480

# %%
x2 = test_df['title'].unique()

# %%
len(x2)
# Out:
# 422

# %%
x = pd.merge(test_df, train_df, left_on='title', right_on='title')['title'].unique()

# %%
len(x)
# Out:
# 395
