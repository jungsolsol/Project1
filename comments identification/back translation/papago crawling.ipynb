# %%
# !pip install selenium

# %%
from selenium import webdriver
import time

driver1 = webdriver.Chrome('./chromedriver/chromedriver.exe')
driver2 = webdriver.Chrome('./chromedriver/chromedriver.exe')

# 파파고 접속
driver1.get('https://papago.naver.com/?sk=ko&tk=en')
driver2.get('https://papago.naver.com/?sk=en&tk=ko&hn=0')
# Out:
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/2807078385.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver1 = webdriver.Chrome('./chromedriver/chromedriver.exe')
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/2807078385.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver2 = webdriver.Chrome('./chromedriver/chromedriver.exe')

# %%
import pandas as pd

# %%
train_df = pd.read_csv('/자료/뜸부기/2021년/이어드림 프로젝트/모의 경진 대회/comments identification/data/train.csv')

# %%
train_df.title
# Out:
# 0              "'미스터 션샤인' 변요한, 김태리와 같은 양복 입고 학당 방문! 이유는?"
# 1       "[SC현장]""극사실주의 현실♥""…'가장 보통의 연애' 김래원X공효진, 16년만...
# 2                  "손연재, 리듬체조 학원 선생님 ""하고 싶은 일 해서 행복하다"""
# 3                    "'섹션TV' 김해숙 ""'허스토리' 촬영 후 우울증 얻었다"""
# 4       "[단독] 임현주 아나운서 “‘노브라 챌린지’ 방송 덕에 낸 용기, 자연스런 논의의...
#                               ...
# 8362                    "배우 이필립, SNS 스타 연인에게 초호화 프러포즈 눈길"
# 8363    "[SC이슈]""마약·백스텝·김새롬 탓"" '실형 피한' 이찬오, 이미지는 치명상(...
# 8364          "[POP이슈]""그들만의 세상""…홍상수♥김민희, 새해데이트에 '반응싸늘'"
# 8365                     [종합] '시크릿 마더' 김소연 누가 죽였나…송윤아와 갈등
# 8366                   "허지웅·소속사 ""악성림프종 진단, 치료 전념"" (공식)"
# Name: title, Length: 8367, dtype: object

# %%
chinese = {
'故': '고', 
'無': '무',
'美': '미',
'韓': '한',
'中': '중',
'日': '일',
'父': '부',
'新': '신',
'母': '모',
'多': '다',
'行': '행',
'前': '전',
'軍': '군',
'家': '가',
'史': '사',
'男': '남',
'子': '자',
'大': '대',
'心': '심', 
'人': '인',
'女': '여', 
'眞': '진',
'愛': '애',
'色': '색',
'性': '성',
'役': '역',
'神': '신',
'有': '유',
'勝': '승',
'伊': '이',
'檢': '검',
'女': '녀'
}

# %%
for char in chinese:
    train_df["title"] = train_df["title"].str.replace(pat=char, repl=chinese[char], regex=True)

# %%
train_df["title"] = train_df["title"].str.replace(pat=r'\[(.{1,10})\]', repl=r'', regex=True)
train_df["title"] = train_df["title"].str.replace(pat=r'\((.{1,10})\)', repl=r'', regex=True)
train_df["title"] = train_df["title"].str.replace(pat=r'ing', repl=r'중', regex=True)
train_df["title"] = train_df["title"].str.replace(pat=r'섹션TV', repl=r'', regex=True)

# %%
train_df["title"] = train_df["title"].str.replace(pat=r'[^\w]', repl=r' ', regex=True)

# %%
train_df["title"] = train_df["title"].str.replace(pat=r' {2,10}', repl=r' ', regex=True)
train_df["title"] = train_df["title"].str.replace(pat=r'^ ', repl=r'', regex=True)
train_df["title"] = train_df["title"].str.replace(pat=r' $', repl=r'', regex=True)

# %%
train_df["title"] = train_df["title"].str.replace(pat=r'다$', repl=r'다.', regex=True)

# %%
train_df
# Out:
#                                            title  \
# 0            미스터 션샤인 변요한 김태리와 같은 양복 입고 학당 방문 이유는
# 1           극사실주의 현실 가장 보통의 연애 김래원X공효진 16년만의 랑데부
# 2               손연재 리듬체조 학원 선생님 하고 싶은 일 해서 행복하다.
# 3                         김해숙 허스토리 촬영 후 우울증 얻었다.
# 4     임현주 아나운서 노브라 챌린지 방송 덕에 낸 용기 자연스런 논의의 창 됐으면
# ...                                          ...
# 8362              배우 이필립 SNS 스타 연인에게 초호화 프러포즈 눈길
# 8363             마약 백스텝 김새롬 탓 실형 피한 이찬오 이미지는 치명상
# 8364                 그들만의 세상 홍상수 김민희 새해데이트에 반응싸늘
# 8365                   시크릿 마더 김소연 누가 죽였나 송윤아와 갈등
# 8366                      허지웅 소속사 악성림프종 진단 치료 전념
#
#                                                 comment    bias  hate
# 0                                        김태리 정말 연기잘해 진짜    none  none
# 1                              공효진 발연기나이질생각이읍던데 왜계속주연일까    none  hate
# 2     누구처럼 돈만 밝히는 저급인생은 살아가지마시길~~ 행복은 머니순이 아니니깐 작은거에...  others  hate
# 3                                              일본 축구 져라    none  none
# 4                            난 절대로 임현주 욕하는인간이랑은 안논다 @.@    none  none
# ...                                                 ...     ...   ...
# 8362  아니 근데.튜닝한사람은 프러포즈받지도.결혼도못함?ㅋㅋㅋ지들은 돈없어서 못하는것들이ㅋ...  others  hate
# 8363  그러니깐 여자를 잘만나야되~징글징글한것들 만나면 인생 끝가지 돌아가게 되는듯.. 근...  gender  hate
# 8364  참으로 아름다운 커플입니다. 늘 행복하시고 새해에도 늘 꽃길만 걸으시길 축원합니다 ...    none  none
# 8365                                            재미가 없어요    none  none
# 8366                                              쭉 쉬세요    none  hate
#
# [8367 rows x 4 columns]

# %%
train_df["title"][0]
# Out:
# '미스터 션샤인 변요한 김태리와 같은 양복 입고 학당 방문 이유는'

# %%
back_tran_title = []
for string in train_df["title"]:
    try:
        driver1.find_element_by_xpath('//*[@id="sourceEditArea"]/button').click()
    except:
        pass
    driver1.find_element_by_xpath('//*[@id="sourceEditArea"]').send_keys('1' + string) # 첫 입력 글짜가 짤리는 현상있었서 1을 추가했다.
    driver1.find_element_by_css_selector('#btnTranslate').click()
    time.sleep(1)
    transResult = driver1.find_element_by_xpath('//*[@id="txtTarget"]').text

    try:
        driver2.find_element_by_xpath('//*[@id="sourceEditArea"]/button').click()
    except:
        pass
    driver2.find_element_by_xpath('//*[@id="sourceEditArea"]').send_keys('1' + transResult)
    driver2.find_element_by_css_selector('#btnTranslate').click()
    time.sleep(1)
    back_tran_title.append(driver2.find_element_by_xpath('//*[@id="txtTarget"]').text)
# Out:
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/1898641319.py:4: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver1.find_element_by_xpath('//*[@id="sourceEditArea"]/button').click()
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/1898641319.py:7: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver1.find_element_by_xpath('//*[@id="sourceEditArea"]').send_keys('1' + string) # 첫 입력 글짜가 짤리는 현상있었서 1을 추가했다.
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/1898641319.py:8: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver1.find_element_by_css_selector('#btnTranslate').click()
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/1898641319.py:10: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   transResult = driver1.find_element_by_xpath('//*[@id="txtTarget"]').text
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/1898641319.py:13: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver2.find_element_by_xpath('//*[@id="sourceEditArea"]/button').click()
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/1898641319.py:16: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver2.find_element_by_xpath('//*[@id="sourceEditArea"]').send_keys('1' + transResult)
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/1898641319.py:17: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver2.find_element_by_css_selector('#btnTranslate').click()
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/1898641319.py:19: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   back_tran_title.append(driver2.find_element_by_xpath('//*[@id="txtTarget"]').text)

# %%
train_df['papago title'] = back_tran_title
back_tran_title = []

# %%
back_tran_comment = []
for string in train_df["comment"]:
    try:
        driver1.find_element_by_xpath('//*[@id="sourceEditArea"]/button').click()
    except:
        pass
    driver1.find_element_by_xpath('//*[@id="sourceEditArea"]').send_keys('1' + string) # 첫 입력 글짜가 짤리는 현상있었서 1을 추가했다.
    driver1.find_element_by_css_selector('#btnTranslate').click()
    time.sleep(1)
    transResult = driver1.find_element_by_xpath('//*[@id="txtTarget"]').text

    try:
        driver2.find_element_by_xpath('//*[@id="sourceEditArea"]/button').click()
    except:
        pass
    driver2.find_element_by_xpath('//*[@id="sourceEditArea"]').send_keys('1' + transResult)
    driver2.find_element_by_css_selector('#btnTranslate').click()
    time.sleep(1)
    back_tran_comment.append(driver2.find_element_by_xpath('//*[@id="txtTarget"]').text)
# Out:
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/3464943573.py:4: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver1.find_element_by_xpath('//*[@id="sourceEditArea"]/button').click()
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/3464943573.py:7: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver1.find_element_by_xpath('//*[@id="sourceEditArea"]').send_keys('1' + string) # 첫 입력 글짜가 짤리는 현상있었서 1을 추가했다.
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/3464943573.py:8: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver1.find_element_by_css_selector('#btnTranslate').click()
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/3464943573.py:10: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   transResult = driver1.find_element_by_xpath('//*[@id="txtTarget"]').text
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/3464943573.py:13: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver2.find_element_by_xpath('//*[@id="sourceEditArea"]/button').click()
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/3464943573.py:16: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver2.find_element_by_xpath('//*[@id="sourceEditArea"]').send_keys('1' + transResult)
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/3464943573.py:17: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver2.find_element_by_css_selector('#btnTranslate').click()
# C:\Users\김대영\AppData\Local\Temp/ipykernel_15440/3464943573.py:19: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   back_tran_comment.append(driver2.find_element_by_xpath('//*[@id="txtTarget"]').text)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15440/3464943573.py in <module>
#      17     driver2.find_element_by_css_selector('#btnTranslate').click()
#      18     time.sleep(1)
# ---> 19     back_tran_comment.append(driver2.find_element_by_xpath('//*[@id="txtTarget"]').text)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     519             stacklevel=2,
#     520         )
# --> 521         return self.find_element(by=By.XPATH, value=xpath)
#     522
#     523     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1246             value = '[name="%s"]' % value
#    1247
# -> 1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
#    1250             'value': value})['value']
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: session deleted because of page crash
# from unknown error: cannot determine loading status
# from tab crashed
#   (Session info: chrome=98.0.4758.102)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x006C69A3+2582947]
# 	Ordinal0 [0x0065A6D1+2139857]
# 	Ordinal0 [0x00553960+1063264]
# 	Ordinal0 [0x00546384+1008516]
# 	Ordinal0 [0x00545FE3+1007587]
# 	Ordinal0 [0x005455F0+1005040]
# 	Ordinal0 [0x00544727+1001255]
# 	Ordinal0 [0x00544AF7+1002231]
# 	Ordinal0 [0x0054EF9F+1044383]
# 	Ordinal0 [0x0055962B+1087019]
# 	Ordinal0 [0x0055BD40+1097024]
# 	Ordinal0 [0x00544DF6+1002998]
# 	Ordinal0 [0x005592AD+1086125]
# 	Ordinal0 [0x005A8240+1409600]
# 	Ordinal0 [0x00598366+1344358]
# 	Ordinal0 [0x00575176+1200502]
# 	Ordinal0 [0x00576066+1204326]
# 	GetHandleVerifier [0x0086BE02+1675858]
# 	GetHandleVerifier [0x0092036C+2414524]
# 	GetHandleVerifier [0x0075BB01+560977]
# 	GetHandleVerifier [0x0075A8D3+556323]
# 	Ordinal0 [0x0066020E+2163214]
# 	Ordinal0 [0x00665078+2183288]
# 	Ordinal0 [0x006651C0+2183616]
# 	Ordinal0 [0x0066EE1C+2223644]
# 	BaseThreadInitThunk [0x76FFFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x772C7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x772C7A6E+238]

# %%
train_df['papago comment'] = back_tran_comment
back_tran_comment = []

# %%
train_df.to_csv('/자료/뜸부기/2021년/이어드림 프로젝트/모의 경진 대회/comments identification/data/papago train.csv', index=False)

# %%
len(back_tran_comment)
# Out:
# 8367

# %%
len(train_df)
# Out:
# 8367

# %%
emty = [None for i in range(4424)]

# %%
back_tran_comment = back_tran_comment + emty
