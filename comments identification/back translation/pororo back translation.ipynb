# %%
# !pip install pororo
# Out:
# ...
#      |████████████████████████████████| 256 kB 7.5 MB/s
# ...
#      |████████████████████████████████| 748.8 MB 17 kB/s
# ...
#      |████████████████████████████████| 3.5 MB 41.7 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 39.1 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 37.8 MB/s
# ...
#      |████████████████████████████████| 468 kB 51.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 46.0 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.1 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 39.5 MB/s
# ...
#      |████████████████████████████████| 5.9 MB 33.6 MB/s
# ...
#      |████████████████████████████████| 42.4 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 90 kB 10.1 MB/s
# ...
#      |████████████████████████████████| 145 kB 50.9 MB/s
# ...
#      |████████████████████████████████| 748 kB 43.6 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 45.5 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 596 kB 49.2 MB/s
# ...

# %%
from pororo import Pororo

# %%
mt = Pororo(task="translation", lang="multi")

# %%
result1 = mt("미스터 션샤인 변요한 김태리와 같은 양복 입고 학당 방문 이유는", src="ko", tgt="en")
print(result1)
result2 = mt(result1, src="en", tgt="ko")
print(result2)
# Out:
# The reason why Mr. Sunshine's visit to the school in a suit like Kim Tae-ri, Byun Yo-han,
# 선샤인 씨가 변요한 김태리와 같은 정장을 입고 학교를 방문한 이유는 그 때문이다.

# %%
import pandas as pd

# %%
train_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/traffic forecasting/Project1/comments identification/data/train.csv')

# %%
chinese = {
'故': '고', 
'無': '무',
'美': '미',
'韓': '한',
'中': '중',
'日': '일',
'父': '부',
'新': '신',
'母': '모',
'多': '다',
'行': '행',
'前': '전',
'軍': '군',
'家': '가',
'史': '사',
'男': '남',
'子': '자',
'大': '대',
'心': '심', 
'人': '인',
'女': '여', 
'眞': '진',
'愛': '애',
'色': '색',
'性': '성',
'役': '역',
'神': '신',
'有': '유',
'勝': '승',
'伊': '이',
'檢': '검',
'女': '녀'
}

# %%
for char in chinese:
    train_df["title"] = train_df["title"].str.replace(pat=char, repl=chinese[char], regex=True)

# %%
train_df["title"] = train_df["title"].str.replace(pat=r'\[(.{1,10})\]', repl=r'', regex=True)
train_df["title"] = train_df["title"].str.replace(pat=r'\((.{1,10})\)', repl=r'', regex=True)
train_df["title"] = train_df["title"].str.replace(pat=r'ing', repl=r'중', regex=True)
train_df["title"] = train_df["title"].str.replace(pat=r'섹션TV', repl=r'', regex=True)

# %%
train_df["title"] = train_df["title"].str.replace(pat=r'[^\w]', repl=r' ', regex=True)

# %%
train_df["title"] = train_df["title"].str.replace(pat=r' {2,10}', repl=r' ', regex=True)
train_df["title"] = train_df["title"].str.replace(pat=r'^ ', repl=r'', regex=True)
train_df["title"] = train_df["title"].str.replace(pat=r' $', repl=r'', regex=True)

# %%
train_df["title"] = train_df["title"].str.replace(pat=r'다$', repl=r'다.', regex=True)

# %%
# 중단후 다시 시작
import pandas as pd
pororo = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/traffic forecasting/Project1/comments identification/data/pororo train.csv')

# %%
pororo = pororo.fillna('0')

# %%
pororo
# Out:
#                                            title  ...  hate
# 0            미스터 션샤인 변요한 김태리와 같은 양복 입고 학당 방문 이유는  ...  none
# 1           극사실주의 현실 가장 보통의 연애 김래원X공효진 16년만의 랑데부  ...  hate
# 2               손연재 리듬체조 학원 선생님 하고 싶은 일 해서 행복하다.  ...  hate
# 3                         김해숙 허스토리 촬영 후 우울증 얻었다.  ...  none
# 4     임현주 아나운서 노브라 챌린지 방송 덕에 낸 용기 자연스런 논의의 창 됐으면  ...  none
# ...                                          ...  ...   ...
# 8362              배우 이필립 SNS 스타 연인에게 초호화 프러포즈 눈길  ...  hate
# 8363             마약 백스텝 김새롬 탓 실형 피한 이찬오 이미지는 치명상  ...  hate
# 8364                 그들만의 세상 홍상수 김민희 새해데이트에 반응싸늘  ...  none
# 8365                   시크릿 마더 김소연 누가 죽였나 송윤아와 갈등  ...  none
# 8366                      허지웅 소속사 악성림프종 진단 치료 전념  ...  hate
#
# [8367 rows x 4 columns]

# %%
back_tran_title = []
for index, tran in enumerate(pororo['pororo title']):
    if index % 100 == 0:
        print(index)

    if tran == '0':
        string = pororo['title'].iloc[index]

        transResult = mt(string, src="ko", tgt="en")

        back_tran_title.append(mt(transResult, src="en", tgt="ko"))
    else:
        back_tran_title.append(tran)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300

# %%
len(back_tran_title)
# Out:
# 2650

# %%
back_tran_title = back_tran_title + [None for _ in range(8367-2650)]

# %%
pororo['pororo title'] = back_tran_title

# %%
pororo.to_csv('/content/drive/MyDrive/Colab Notebooks/traffic forecasting/Project1/comments identification/data/pororo train.csv', index=False)

# %%
pororo
# Out:
#                                            title  ...  hate
# 0            미스터 션샤인 변요한 김태리와 같은 양복 입고 학당 방문 이유는  ...  none
# 1           극사실주의 현실 가장 보통의 연애 김래원X공효진 16년만의 랑데부  ...  hate
# 2               손연재 리듬체조 학원 선생님 하고 싶은 일 해서 행복하다.  ...  hate
# 3                         김해숙 허스토리 촬영 후 우울증 얻었다.  ...  none
# 4     임현주 아나운서 노브라 챌린지 방송 덕에 낸 용기 자연스런 논의의 창 됐으면  ...  none
# ...                                          ...  ...   ...
# 8362              배우 이필립 SNS 스타 연인에게 초호화 프러포즈 눈길  ...  hate
# 8363             마약 백스텝 김새롬 탓 실형 피한 이찬오 이미지는 치명상  ...  hate
# 8364                 그들만의 세상 홍상수 김민희 새해데이트에 반응싸늘  ...  none
# 8365                   시크릿 마더 김소연 누가 죽였나 송윤아와 갈등  ...  none
# 8366                      허지웅 소속사 악성림프종 진단 치료 전념  ...  hate
#
# [8367 rows x 4 columns]

# %%
len(back_tran_title)
# Out:
# 375

# %%
len(train_df)
# Out:
# 8367

# %%
back_tran_title = back_tran_title + [None for _ in range(8367-375)]

# %%
train_df['pororo title'] = back_tran_title
back_tran_title = []
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-22b323150ae2> in <module>()
# ----> 1 train_df['pororo title'] = back_tran_title
#       2 back_tran_title = []
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# ...

# %%
back_tran_comment = []
for string in train_df["comment"]:
    
    transResult = mt(string, src="ko", tgt="en")

    back_tran_comment.append(mt(result1, src="en", tgt="ko"))

# %%
back_tran_comment
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-916266adde07> in <module>()
# ----> 1 back_tran_comment
#
# NameError: name 'back_tran_comment' is not defined

# %%
train_df['pororo comment'] = back_tran_comment
back_tran_comment = []

# %%
train_df.to_csv('/content/drive/MyDrive/Colab Notebooks/traffic forecasting/Project1/comments identification/data/pororo train.csv', index=False)

# %%
train_df.rename(columns = {'comment' : 'pororo title'}, inplace = True)

# %%
train_df
# Out:
#                                            title  ...  hate
# 0            미스터 션샤인 변요한 김태리와 같은 양복 입고 학당 방문 이유는  ...  none
# 1           극사실주의 현실 가장 보통의 연애 김래원X공효진 16년만의 랑데부  ...  hate
# 2               손연재 리듬체조 학원 선생님 하고 싶은 일 해서 행복하다.  ...  hate
# 3                         김해숙 허스토리 촬영 후 우울증 얻었다.  ...  none
# 4     임현주 아나운서 노브라 챌린지 방송 덕에 낸 용기 자연스런 논의의 창 됐으면  ...  none
# ...                                          ...  ...   ...
# 8362              배우 이필립 SNS 스타 연인에게 초호화 프러포즈 눈길  ...  hate
# 8363             마약 백스텝 김새롬 탓 실형 피한 이찬오 이미지는 치명상  ...  hate
# 8364                 그들만의 세상 홍상수 김민희 새해데이트에 반응싸늘  ...  none
# 8365                   시크릿 마더 김소연 누가 죽였나 송윤아와 갈등  ...  none
# 8366                      허지웅 소속사 악성림프종 진단 치료 전념  ...  hate
#
# [8367 rows x 4 columns]
